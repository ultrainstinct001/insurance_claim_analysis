# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
claims=pd.read_csv('claims.csv')
cust_demo=pd.read_csv('cust_demographics.csv')

# %%
claims.head()
# Out:
#    claim_id  customer_id      incident_cause  claim_date claim_area  \
# 0  54004764     21868593        Driver error  11/27/2017       Auto
# 1  33985796     75740424               Crime  10/03/2018       Home
# 2  53522022     30308357  Other driver error  02/02/2018       Auto
# 3  13015401     47830476      Natural causes  06/17/2018       Auto
# 4  22890252     19269962               Crime  01/13/2018       Auto
#
#   police_report     claim_type claim_amount  total_policy_claims fraudulent
# 0            No  Material only        $2980                  1.0         No
# 1       Unknown  Material only        $2980                  3.0         No
# 2            No  Material only      $3369.5                  1.0        Yes
# 3            No  Material only        $1680                  1.0         No
# 4            No  Material only        $2680                  1.0         No

# %%
cust_demo.head()
# Out:
#     CUST_ID  gender DateOfBirth State       Contact   Segment
# 0  21868593  Female   12-Jan-79    VT  789-916-8172  Platinum
# 1  75740424  Female   13-Jan-70    ME  265-543-1264    Silver
# 2  30308357  Female   11-Mar-84    TN  798-631-4758    Silver
# 3  47830476  Female   01-May-86    MA  413-187-7945    Silver
# 4  19269962    Male   13-May-77    NV  956-871-8691      Gold

# %%
final = pd.merge(claims,cust_demo,left_on='customer_id',right_on='CUST_ID')

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1085 entries, 0 to 1084
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   claim_id             1085 non-null   int64
#  1   customer_id          1085 non-null   int64
#  2   incident_cause       1085 non-null   object
#  3   claim_date           1085 non-null   object
#  4   claim_area           1085 non-null   object
#  5   police_report        1085 non-null   object
#  6   claim_type           1085 non-null   object
#  7   claim_amount         1020 non-null   object
#  8   total_policy_claims  1075 non-null   float64
#  9   fraudulent           1085 non-null   object
#  10  CUST_ID              1085 non-null   int64
#  11  gender               1085 non-null   object
#  12  DateOfBirth          1085 non-null   object
#  13  State                1085 non-null   object
#  14  Contact              1085 non-null   object
#  15  Segment              1085 non-null   object
# dtypes: float64(1), int64(3), object(12)
# memory usage: 144.1+ KB

# %%
final['DateOfBirth'] = final['DateOfBirth'].apply(lambda x: pd.to_datetime(x))

# %%
final['claim_date'] = final['claim_date'].apply(lambda x: pd.to_datetime(x))
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1085 entries, 0 to 1084
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   claim_id             1085 non-null   int64
#  1   customer_id          1085 non-null   int64
#  2   incident_cause       1085 non-null   object
#  3   claim_date           1085 non-null   datetime64[ns]
#  4   claim_area           1085 non-null   object
#  5   police_report        1085 non-null   object
#  6   claim_type           1085 non-null   object
#  7   claim_amount         1020 non-null   object
#  8   total_policy_claims  1075 non-null   float64
#  9   fraudulent           1085 non-null   object
#  10  CUST_ID              1085 non-null   int64
#  11  gender               1085 non-null   object
#  12  DateOfBirth          1085 non-null   datetime64[ns]
#  13  State                1085 non-null   object
#  14  Contact              1085 non-null   object
#  15  Segment              1085 non-null   object
# dtypes: datetime64[ns](2), float64(1), int64(3), object(10)
# memory usage: 144.1+ KB

# %%
final.head()
# Out:
#    claim_id  customer_id      incident_cause claim_date claim_area  \
# 0  54004764     21868593        Driver error 2017-11-27       Auto
# 1  33985796     75740424               Crime 2018-10-03       Home
# 2  53522022     30308357  Other driver error 2018-02-02       Auto
# 3  63017412     30308357        Driver error 2018-04-04       Auto
# 4  13015401     47830476      Natural causes 2018-06-17       Auto
#
#   police_report     claim_type claim_amount  total_policy_claims fraudulent  \
# 0            No  Material only        $2980                  1.0         No
# 1       Unknown  Material only        $2980                  3.0         No
# 2            No  Material only      $3369.5                  1.0        Yes
# 3            No  Material only        $1950                  6.0         No
# 4            No  Material only        $1680                  1.0         No
#
#     CUST_ID  gender DateOfBirth State       Contact   Segment
# 0  21868593  Female  1979-01-12    VT  789-916-8172  Platinum
# 1  75740424  Female  2070-01-13    ME  265-543-1264    Silver
# 2  30308357  Female  1984-03-11    TN  798-631-4758    Silver
# 3  30308357  Female  1984-03-11    TN  798-631-4758    Silver
# 4  47830476  Female  1986-05-01    MA  413-187-7945    Silver

# %%
final['claim_amount'] = final['claim_amount'].astype('str')
final['claim_amount'] = final['claim_amount'].str.split('$').str[1]
final['claim_amount'] = final['claim_amount'].astype(float)

# %%
final.head()
# Out:
#    claim_id  customer_id      incident_cause claim_date claim_area  \
# 0  54004764     21868593        Driver error 2017-11-27       Auto
# 1  33985796     75740424               Crime 2018-10-03       Home
# 2  53522022     30308357  Other driver error 2018-02-02       Auto
# 3  63017412     30308357        Driver error 2018-04-04       Auto
# 4  13015401     47830476      Natural causes 2018-06-17       Auto
#
#   police_report     claim_type  claim_amount  total_policy_claims fraudulent  \
# 0            No  Material only        2980.0                  1.0         No
# 1       Unknown  Material only        2980.0                  3.0         No
# 2            No  Material only        3369.5                  1.0        Yes
# 3            No  Material only        1950.0                  6.0         No
# 4            No  Material only        1680.0                  1.0         No
#
#     CUST_ID  gender DateOfBirth State       Contact   Segment
# 0  21868593  Female  1979-01-12    VT  789-916-8172  Platinum
# 1  75740424  Female  2070-01-13    ME  265-543-1264    Silver
# 2  30308357  Female  1984-03-11    TN  798-631-4758    Silver
# 3  30308357  Female  1984-03-11    TN  798-631-4758    Silver
# 4  47830476  Female  1986-05-01    MA  413-187-7945    Silver

# %%
final['Aler_flag'] = np.where((final['police_report']=='No'),0,1)
final.head()
# Out:
#    claim_id  customer_id      incident_cause claim_date claim_area  \
# 0  54004764     21868593        Driver error 2017-11-27       Auto
# 1  33985796     75740424               Crime 2018-10-03       Home
# 2  53522022     30308357  Other driver error 2018-02-02       Auto
# 3  63017412     30308357        Driver error 2018-04-04       Auto
# 4  13015401     47830476      Natural causes 2018-06-17       Auto
#
#   police_report     claim_type  claim_amount  total_policy_claims fraudulent  \
# 0            No  Material only        2980.0                  1.0         No
# 1       Unknown  Material only        2980.0                  3.0         No
# 2            No  Material only        3369.5                  1.0        Yes
# 3            No  Material only        1950.0                  6.0         No
# 4            No  Material only        1680.0                  1.0         No
#
#     CUST_ID  gender DateOfBirth State       Contact   Segment  Aler_flag
# 0  21868593  Female  1979-01-12    VT  789-916-8172  Platinum          0
# 1  75740424  Female  2070-01-13    ME  265-543-1264    Silver          1
# 2  30308357  Female  1984-03-11    TN  798-631-4758    Silver          0
# 3  30308357  Female  1984-03-11    TN  798-631-4758    Silver          0
# 4  47830476  Female  1986-05-01    MA  413-187-7945    Silver          0

# %%
final.drop(columns = ['CUST_ID'],inplace = True)
final.head(1)
# Out:
#    claim_id  customer_id incident_cause claim_date claim_area police_report  \
# 0  54004764     21868593   Driver error 2017-11-27       Auto            No
#
#       claim_type  claim_amount  total_policy_claims fraudulent  gender  \
# 0  Material only        2980.0                  1.0         No  Female
#
#   DateOfBirth State       Contact   Segment  Aler_flag
# 0  1979-01-12    VT  789-916-8172  Platinum          0

# %%
final.duplicated().sum()
# Out:
# 0

# %%
final['customer_id'].drop_duplicates(inplace = True)

# %%
final.isna().sum()
# Out:
# claim_id                0
# customer_id             0
# incident_cause          0
# claim_date              0
# claim_area              0
# police_report           0
# claim_type              0
# claim_amount           65
# total_policy_claims    10
# fraudulent              0
# gender                  0
# DateOfBirth             0
# State                   0
# Contact                 0
# Segment                 0
# Aler_flag               0
# dtype: int64

# %%
final['claim_amount'] =final['claim_amount'].fillna(final['claim_amount'].mean())

# %%
final.isna().sum()
# Out:
# claim_id                0
# customer_id             0
# incident_cause          0
# claim_date              0
# claim_area              0
# police_report           0
# claim_type              0
# claim_amount            0
# total_policy_claims    10
# fraudulent              0
# gender                  0
# DateOfBirth             0
# State                   0
# Contact                 0
# Segment                 0
# Aler_flag               0
# dtype: int64

# %%
final['total_policy_claims'] = np.where(final['total_policy_claims'].isna(),final['total_policy_claims'].mean(),final['total_policy_claims'])

# %%
final.head()
# Out:
#    claim_id  customer_id      incident_cause claim_date claim_area  \
# 0  54004764     21868593        Driver error 2017-11-27       Auto
# 1  33985796     75740424               Crime 2018-10-03       Home
# 2  53522022     30308357  Other driver error 2018-02-02       Auto
# 3  63017412     30308357        Driver error 2018-04-04       Auto
# 4  13015401     47830476      Natural causes 2018-06-17       Auto
#
#   police_report     claim_type  claim_amount  total_policy_claims fraudulent  \
# 0            No  Material only        2980.0                  1.0         No
# 1       Unknown  Material only        2980.0                  3.0         No
# 2            No  Material only        3369.5                  1.0        Yes
# 3            No  Material only        1950.0                  6.0         No
# 4            No  Material only        1680.0                  1.0         No
#
#    gender DateOfBirth State       Contact   Segment  Aler_flag
# 0  Female  1979-01-12    VT  789-916-8172  Platinum          0
# 1  Female  2070-01-13    ME  265-543-1264    Silver          1
# 2  Female  1984-03-11    TN  798-631-4758    Silver          0
# 3  Female  1984-03-11    TN  798-631-4758    Silver          0
# 4  Female  1986-05-01    MA  413-187-7945    Silver          0

# %%
final['DOB_Year'] = final['DateOfBirth'].apply(lambda x: x.year)
final.head()
# Out:
#    claim_id  customer_id      incident_cause claim_date claim_area  \
# 0  54004764     21868593        Driver error 2017-11-27       Auto
# 1  33985796     75740424               Crime 2018-10-03       Home
# 2  53522022     30308357  Other driver error 2018-02-02       Auto
# 3  63017412     30308357        Driver error 2018-04-04       Auto
# 4  13015401     47830476      Natural causes 2018-06-17       Auto
#
#   police_report     claim_type  claim_amount  total_policy_claims fraudulent  \
# 0            No  Material only        2980.0                  1.0         No
# 1       Unknown  Material only        2980.0                  3.0         No
# 2            No  Material only        3369.5                  1.0        Yes
# 3            No  Material only        1950.0                  6.0         No
# 4            No  Material only        1680.0                  1.0         No
#
#    gender DateOfBirth State       Contact   Segment  Aler_flag  DOB_Year
# 0  Female  1979-01-12    VT  789-916-8172  Platinum          0      1979
# 1  Female  2070-01-13    ME  265-543-1264    Silver          1      2070
# 2  Female  1984-03-11    TN  798-631-4758    Silver          0      1984
# 3  Female  1984-03-11    TN  798-631-4758    Silver          0      1984
# 4  Female  1986-05-01    MA  413-187-7945    Silver          0      1986

# %%
final['current_year'] = pd.to_datetime('today').year

# %%
final['Age'] = final['current_year'] - final['DOB_Year']
final.head(1)
# Out:
#    claim_id  customer_id incident_cause claim_date claim_area police_report  \
# 0  54004764     21868593   Driver error 2017-11-27       Auto            No
#
#       claim_type  claim_amount  total_policy_claims fraudulent  gender  \
# 0  Material only        2980.0                  1.0         No  Female
#
#   DateOfBirth State       Contact   Segment  Aler_flag  DOB_Year  \
# 0  1979-01-12    VT  789-916-8172  Platinum          0      1979
#
#    current_year  Age
# 0          2023   44

# %%
final.drop(columns =['current_year'],inplace = True)

# %%
final['Age_Type'] = np.where(((final['Age'].astype(int)<18)),"Children",
                         np.where(((final['Age'].astype(int)>=18) & (final['Age'].astype(int)<30)),"Youth",
                                  np.where((final['Age'].astype(int)>=30) & (final['Age'].astype(int)<60),"Adult","Senior" )))

# %%
final.head()
# Out:
#    claim_id  customer_id      incident_cause claim_date claim_area  \
# 0  54004764     21868593        Driver error 2017-11-27       Auto
# 1  33985796     75740424               Crime 2018-10-03       Home
# 2  53522022     30308357  Other driver error 2018-02-02       Auto
# 3  63017412     30308357        Driver error 2018-04-04       Auto
# 4  13015401     47830476      Natural causes 2018-06-17       Auto
#
#   police_report     claim_type  claim_amount  total_policy_claims fraudulent  \
# 0            No  Material only        2980.0                  1.0         No
# 1       Unknown  Material only        2980.0                  3.0         No
# 2            No  Material only        3369.5                  1.0        Yes
# 3            No  Material only        1950.0                  6.0         No
# 4            No  Material only        1680.0                  1.0         No
#
#    gender DateOfBirth State       Contact   Segment  Aler_flag  DOB_Year  Age  \
# 0  Female  1979-01-12    VT  789-916-8172  Platinum          0      1979   44
# 1  Female  2070-01-13    ME  265-543-1264    Silver          1      2070  -47
# 2  Female  1984-03-11    TN  798-631-4758    Silver          0      1984   39
# 3  Female  1984-03-11    TN  798-631-4758    Silver          0      1984   39
# 4  Female  1986-05-01    MA  413-187-7945    Silver          0      1986   37
#
#    Age_Type
# 0     Adult
# 1  Children
# 2     Adult
# 3     Adult
# 4     Adult

# %%
final.groupby(['Segment'])[['claim_amount']].mean()
# Out:
#           claim_amount
# Segment
# Gold      12829.631974
# Platinum  12341.952267
# Silver    12208.435570

# %%
final_incident_cause = final[(final['incident_cause'] == 'Driver error') | (final['incident_cause'] == 'Other driver error')]

# %%
final_incident_cause[(final_incident_cause['State'] =='TX') |( final_incident_cause['State'] == 'DE') |(final_incident_cause['State'] == 'AK')]
# Out:
#       claim_id  customer_id      incident_cause claim_date claim_area  \
# 39    70399158     26489135        Driver error 2017-07-01       Auto
# 101    4506676      2632562  Other driver error 2018-05-14       Home
# 103   82144259     92752865        Driver error 2017-04-25       Auto
# 118   65335959     61810954  Other driver error 2018-09-19       Auto
# 147   26716331      3159546  Other driver error 2017-04-25       Auto
# 187   21550521     68772500        Driver error 2018-08-30       Auto
# 188   69348631       154557        Driver error 2018-04-10       Auto
# 199   46572741     82415154  Other driver error 2017-06-11       Auto
# 246    7238381       684748  Other driver error 2018-07-14       Auto
# 263   31574986     11321295        Driver error 2017-02-03       Auto
# 275   34621474     54094880  Other driver error 2017-02-17       Auto
# 277   93028492     62204138        Driver error 2017-10-31       Auto
# 322   87329176     77510822  Other driver error 2018-10-30       Auto
# 355   49252712     76314493  Other driver error 2017-09-14       Home
# 362   34596802     94643289        Driver error 2018-03-14       Auto
# 376   92399694     92971195  Other driver error 2018-09-26       Home
# 381      70068      4669941        Driver error 2017-11-06       Auto
# 389   34691767     84750181  Other driver error 2017-03-09       Home
# 430   22577147     66433138        Driver error 2017-02-23       Auto
# 453   99281527     32464636        Driver error 2017-10-31       Auto
# 524    9124181     19796899  Other driver error 2018-04-04       Auto
# 538   37688454     13687085        Driver error 2018-01-13       Auto
# 551   86096444     65899365        Driver error 2018-07-14       Auto
# 570    9129053     85250389  Other driver error 2017-03-02       Auto
# 574   53831641     15820948        Driver error 2017-09-27       Auto
# 607   30280492     84147585        Driver error 2017-01-07       Auto
# 608   78221963     84147585        Driver error 2018-04-10       Auto
# 614   54642809     39959491        Driver error 2018-09-06       Auto
# 650   40283824      9205013        Driver error 2018-06-17       Auto
# 706    6365892     42083451        Driver error 2017-08-31       Auto
# 849   94983900     18282409        Driver error 2017-08-11       Auto
# 926    7136079     29903212        Driver error 2018-06-17       Auto
# 929   21146312     77006226        Driver error 2018-02-15       Auto
# 942   77192370     47415706  Other driver error 2017-08-04       Auto
# 984   17396013     44050095        Driver error 2017-03-22       Auto
# 1016  12612736     74787956        Driver error 2017-09-14       Auto
#
#      police_report           claim_type  claim_amount  total_policy_claims  \
# 39              No        Material only   1110.000000                  1.0
# 101        Unknown        Material only   1400.000000                  1.0
# 103             No          Injury only  12467.681373                  1.0
# 118        Unknown  Material and injury  36620.000000                  1.0
# 147             No          Injury only  17590.000000                  4.0
# 187        Unknown        Material only   2320.000000                  1.0
# 188             No          Injury only  12467.681373                  1.0
# 199             No  Material and injury  15240.000000                  1.0
# 246             No        Material only   2920.000000                  2.0
# 263             No        Material only   2460.000000                  2.0
# 275             No        Material only   1529.500000                  1.0
# 277        Unknown        Material only   2691.000000                  1.0
# 322        Unknown        Material only  12467.681373                  2.0
# 355             No        Material only  12467.681373                  1.0
# 362             No  Material and injury  45287.000000                  1.0
# 376             No        Material only   1140.000000                  1.0
# 381        Unknown          Injury only  29900.000000                  1.0
# 389             No        Material only   2370.000000                  4.0
# 430             No  Material and injury  21447.500000                  2.0
# 453             No        Material only   2323.000000                  1.0
# 524            Yes  Material and injury  24667.500000                  1.0
# 538        Unknown          Injury only  16760.000000                  1.0
# 551             No  Material and injury  34160.000000                  1.0
# 570        Unknown          Injury only  24380.000000                  1.0
# 574            Yes  Material and injury  14570.000000                  1.0
# 607        Unknown        Material only   2380.000000                  1.0
# 608            Yes          Injury only  14430.000000                  4.0
# 614        Unknown        Material only   2720.000000                  1.0
# 650            Yes  Material and injury  23430.000000                  1.0
# 706             No        Material only   2400.000000                  1.0
# 849             No          Injury only  31020.000000                  2.0
# 926             No        Material only   2668.000000                  2.0
# 929             No        Material only   2930.000000                  1.0
# 942        Unknown  Material and injury  18457.500000                  1.0
# 984        Unknown  Material and injury  20458.500000                  1.0
# 1016       Unknown        Material only  12467.681373                  1.0
#
#      fraudulent  gender DateOfBirth State       Contact   Segment  Aler_flag  \
# 39           No    Male  1994-10-05    DE  654-456-1493  Platinum          0
# 101          No  Female  1985-12-14    AK  498-597-9658  Platinum          1
# 103          No    Male  1986-01-30    AK  143-219-5498    Silver          0
# 118          No    Male  2069-05-18    TX  724-493-6179    Silver          1
# 147          No    Male  1987-10-20    TX  586-129-9752  Platinum          0
# 187          No    Male  1989-11-10    TX  562-259-5432    Silver          1
# 188         Yes  Female  1978-05-23    DE  962-879-1238  Platinum          0
# 199          No  Female  1980-03-08    DE  578-942-1542  Platinum          0
# 246          No    Male  1977-08-03    AK  613-385-2863      Gold          0
# 263          No    Male  2065-11-13    DE  429-596-2169  Platinum          0
# 275         Yes    Male  1984-06-01    DE  568-481-7418    Silver          0
# 277         Yes  Female  1989-12-15    DE  471-934-4961  Platinum          1
# 322          No  Female  1986-03-18    AK  436-934-7156    Silver          1
# 355          No  Female  2061-10-02    DE  389-764-4853    Silver          0
# 362         Yes    Male  1998-04-24    AK  317-612-1425    Silver          0
# 376          No    Male  1975-02-02    DE  892-173-4657      Gold          0
# 381         Yes    Male  1982-08-03    AK  761-462-3458  Platinum          1
# 389          No  Female  1993-05-16    AK  419-431-6251  Platinum          0
# 430         Yes    Male  1978-06-27    TX  752-617-3867      Gold          0
# 453         Yes  Female  1988-08-25    DE  862-247-1496      Gold          0
# 524         Yes  Female  1975-12-17    TX  725-873-8239      Gold          1
# 538          No    Male  1997-11-18    DE  137-146-7356  Platinum          1
# 551          No  Female  1973-07-25    TX  135-971-8567  Platinum          0
# 570         Yes  Female  2067-05-08    TX  827-367-5247  Platinum          1
# 574          No    Male  2064-02-22    TX  583-641-3184    Silver          1
# 607          No    Male  2072-10-18    AK  743-569-4783      Gold          1
# 608          No    Male  2072-10-18    AK  743-569-4783      Gold          1
# 614          No  Female  1995-04-07    DE  139-742-5417    Silver          1
# 650          No    Male  2063-12-11    DE  239-368-6759  Platinum          1
# 706          No    Male  2067-11-23    AK  689-375-9463  Platinum          0
# 849          No  Female  1973-09-29    AK  326-215-7361      Gold          0
# 926         Yes    Male  1989-12-16    DE  279-918-3268  Platinum          0
# 929          No  Female  1998-02-13    TX  641-295-5498  Platinum          0
# 942         Yes  Female  2061-08-08    DE  179-574-5837      Gold          1
# 984         Yes    Male  1977-06-04    DE  314-298-9257  Platinum          1
# 1016         No    Male  1989-06-19    TX  679-514-5894      Gold          1
#
#       DOB_Year  Age  Age_Type
# 39        1994   29     Youth
# 101       1985   38     Adult
# 103       1986   37     Adult
# 118       2069  -46  Children
# 147       1987   36     Adult
# 187       1989   34     Adult
# 188       1978   45     Adult
# 199       1980   43     Adult
# 246       1977   46     Adult
# 263       2065  -42  Children
# 275       1984   39     Adult
# 277       1989   34     Adult
# 322       1986   37     Adult
# 355       2061  -38  Children
# 362       1998   25     Youth
# 376       1975   48     Adult
# 381       1982   41     Adult
# 389       1993   30     Adult
# 430       1978   45     Adult
# 453       1988   35     Adult
# 524       1975   48     Adult
# 538       1997   26     Youth
# 551       1973   50     Adult
# 570       2067  -44  Children
# 574       2064  -41  Children
# 607       2072  -49  Children
# 608       2072  -49  Children
# 614       1995   28     Youth
# 650       2063  -40  Children
# 706       2067  -44  Children
# 849       1973   50     Adult
# 926       1989   34     Adult
# 929       1998   25     Youth
# 942       2061  -38  Children
# 984       1977   46     Adult
# 1016      1989   34     Adult

# %%
final.head(1)
# Out:
#    claim_id  customer_id incident_cause claim_date claim_area police_report  \
# 0  54004764     21868593   Driver error 2017-11-27       Auto            No
#
#       claim_type  claim_amount  total_policy_claims fraudulent  gender  \
# 0  Material only        2980.0                  1.0         No  Female
#
#   DateOfBirth State       Contact   Segment  Aler_flag  DOB_Year  Age Age_Type
# 0  1979-01-12    VT  789-916-8172  Platinum          0      1979   44    Adult

# %%
final_aggregate = final.pivot_table(columns ='Segment',index = 'gender',values ='claim_amount',aggfunc =sum)
final_aggregate
# Out:
# Segment          Gold      Platinum        Silver
# gender
# Female   2.109738e+06  2.369484e+06  1.901912e+06
# Male     2.701374e+06  2.098303e+06  2.346624e+06

# %%
final_aggregate.plot(kind='pie',subplots=True, labels=['Male','Female'],autopct='%1.2f%%')
# Out:
# array([<Axes: ylabel='Gold'>, <Axes: ylabel='Platinum'>,
#        <Axes: ylabel='Silver'>], dtype=object)

# %%
final.head()
# Out:
#    claim_id  customer_id      incident_cause claim_date claim_area  \
# 0  54004764     21868593        Driver error 2017-11-27       Auto
# 1  33985796     75740424               Crime 2018-10-03       Home
# 2  53522022     30308357  Other driver error 2018-02-02       Auto
# 3  63017412     30308357        Driver error 2018-04-04       Auto
# 4  13015401     47830476      Natural causes 2018-06-17       Auto
#
#   police_report     claim_type  claim_amount  total_policy_claims fraudulent  \
# 0            No  Material only        2980.0                  1.0         No
# 1       Unknown  Material only        2980.0                  3.0         No
# 2            No  Material only        3369.5                  1.0        Yes
# 3            No  Material only        1950.0                  6.0         No
# 4            No  Material only        1680.0                  1.0         No
#
#    gender DateOfBirth State       Contact   Segment  Aler_flag  DOB_Year  Age  \
# 0  Female  1979-01-12    VT  789-916-8172  Platinum          0      1979   44
# 1  Female  2070-01-13    ME  265-543-1264    Silver          1      2070  -47
# 2  Female  1984-03-11    TN  798-631-4758    Silver          0      1984   39
# 3  Female  1984-03-11    TN  798-631-4758    Silver          0      1984   39
# 4  Female  1986-05-01    MA  413-187-7945    Silver          0      1986   37
#
#    Age_Type
# 0     Adult
# 1  Children
# 2     Adult
# 3     Adult
# 4     Adult

# %%
final_incident_cause.head()
# Out:
#    claim_id  customer_id      incident_cause claim_date claim_area  \
# 0  54004764     21868593        Driver error 2017-11-27       Auto
# 2  53522022     30308357  Other driver error 2018-02-02       Auto
# 3  63017412     30308357        Driver error 2018-04-04       Auto
# 8  24050443     21831191  Other driver error 2017-10-04       Auto
# 9  91475471     21831191        Driver error 2018-02-09       Auto
#
#   police_report           claim_type  claim_amount  total_policy_claims  \
# 0            No        Material only        2980.0                  1.0
# 2            No        Material only        3369.5                  1.0
# 3            No        Material only        1950.0                  6.0
# 8            No          Injury only       38306.5                  3.0
# 9       Unknown  Material and injury       36810.0                  1.0
#
#   fraudulent  gender DateOfBirth State       Contact   Segment  Aler_flag  \
# 0         No  Female  1979-01-12    VT  789-916-8172  Platinum          0
# 2        Yes  Female  1984-03-11    TN  798-631-4758    Silver          0
# 3         No  Female  1984-03-11    TN  798-631-4758    Silver          0
# 8        Yes    Male  1977-05-17    NH  419-712-8513      Gold          0
# 9         No    Male  1977-05-17    NH  419-712-8513      Gold          1
#
#    DOB_Year  Age Age_Type
# 0      1979   44    Adult
# 2      1984   39    Adult
# 3      1984   39    Adult
# 8      1977   46    Adult
# 9      1977   46    Adult

# %%
gender_wise = final_incident_cause.groupby(['gender'])[['claim_amount']].sum()

# %%
gender_wise.plot(kind='bar',stacked = True)
# Out:
# <Axes: xlabel='gender'>

# %%
final.head()
# Out:
#    claim_id  customer_id      incident_cause claim_date claim_area  \
# 0  54004764     21868593        Driver error 2017-11-27       Auto
# 1  33985796     75740424               Crime 2018-10-03       Home
# 2  53522022     30308357  Other driver error 2018-02-02       Auto
# 3  63017412     30308357        Driver error 2018-04-04       Auto
# 4  13015401     47830476      Natural causes 2018-06-17       Auto
#
#   police_report     claim_type  claim_amount  total_policy_claims fraudulent  \
# 0            No  Material only        2980.0                  1.0         No
# 1       Unknown  Material only        2980.0                  3.0         No
# 2            No  Material only        3369.5                  1.0        Yes
# 3            No  Material only        1950.0                  6.0         No
# 4            No  Material only        1680.0                  1.0         No
#
#    gender DateOfBirth State       Contact   Segment  Aler_flag  DOB_Year  Age  \
# 0  Female  1979-01-12    VT  789-916-8172  Platinum          0      1979   44
# 1  Female  2070-01-13    ME  265-543-1264    Silver          1      2070  -47
# 2  Female  1984-03-11    TN  798-631-4758    Silver          0      1984   39
# 3  Female  1984-03-11    TN  798-631-4758    Silver          0      1984   39
# 4  Female  1986-05-01    MA  413-187-7945    Silver          0      1986   37
#
#    Age_Type
# 0     Adult
# 1  Children
# 2     Adult
# 3     Adult
# 4     Adult

# %%
fraud = final[final['fraudulent']=='Yes']
fraud.head(1)
# Out:
#    claim_id  customer_id      incident_cause claim_date claim_area  \
# 2  53522022     30308357  Other driver error 2018-02-02       Auto
#
#   police_report     claim_type  claim_amount  total_policy_claims fraudulent  \
# 2            No  Material only        3369.5                  1.0        Yes
#
#    gender DateOfBirth State       Contact Segment  Aler_flag  DOB_Year  Age  \
# 2  Female  1984-03-11    TN  798-631-4758  Silver          0      1984   39
#
#   Age_Type
# 2    Adult

# %%
fraud_age_type =fraud.groupby(['Age_Type'])[['fraudulent']].count()

# %%
fraud_age_type.plot(kind ='bar',stacked = True)
# Out:
# <Axes: xlabel='Age_Type'>

# %%
final.head(1)
# Out:
#    claim_id  customer_id incident_cause claim_date claim_area police_report  \
# 0  54004764     21868593   Driver error 2017-11-27       Auto            No
#
#       claim_type  claim_amount  total_policy_claims fraudulent  gender  \
# 0  Material only        2980.0                  1.0         No  Female
#
#   DateOfBirth State       Contact   Segment  Aler_flag  DOB_Year  Age Age_Type
# 0  1979-01-12    VT  789-916-8172  Platinum          0      1979   44    Adult

# %%
final['Month_no'] = final['claim_date'].apply(lambda x: x.month)
final.head(1)
# Out:
#    claim_id  customer_id incident_cause claim_date claim_area police_report  \
# 0  54004764     21868593   Driver error 2017-11-27       Auto            No
#
#       claim_type  claim_amount  total_policy_claims fraudulent  gender  \
# 0  Material only        2980.0                  1.0         No  Female
#
#   DateOfBirth State       Contact   Segment  Aler_flag  DOB_Year  Age  \
# 0  1979-01-12    VT  789-916-8172  Platinum          0      1979   44
#
#   Age_Type  Month_no
# 0    Adult        11

# %%
final['Year'] = final['claim_date'].apply(lambda x: x.year)

# %%
final_graph = final.groupby(['Year','Month_no'])[['claim_amount']].sum()

# %%
final_graph.plot(kind ='bar',stacked = True)
# Out:
# <Axes: xlabel='Year,Month_no'>

# %%
graph = final.pivot_table(index = ['gender','Age_Type'],columns =['fraudulent'],values = ['claim_amount'],aggfunc = 'mean')

# %%
graph.plot(kind = 'bar',stacked = True)
# Out:
# <Axes: xlabel='gender,Age_Type'>

# %%
final.head()
# Out:
#    claim_id  customer_id      incident_cause claim_date claim_area  \
# 0  54004764     21868593        Driver error 2017-11-27       Auto
# 1  33985796     75740424               Crime 2018-10-03       Home
# 2  53522022     30308357  Other driver error 2018-02-02       Auto
# 3  63017412     30308357        Driver error 2018-04-04       Auto
# 4  13015401     47830476      Natural causes 2018-06-17       Auto
#
#   police_report     claim_type  claim_amount  total_policy_claims fraudulent  \
# 0            No  Material only        2980.0                  1.0         No
# 1       Unknown  Material only        2980.0                  3.0         No
# 2            No  Material only        3369.5                  1.0        Yes
# 3            No  Material only        1950.0                  6.0         No
# 4            No  Material only        1680.0                  1.0         No
#
#    ... DateOfBirth State       Contact   Segment Aler_flag  DOB_Year  Age  \
# 0  ...  1979-01-12    VT  789-916-8172  Platinum         0      1979   44
# 1  ...  2070-01-13    ME  265-543-1264    Silver         1      2070  -47
# 2  ...  1984-03-11    TN  798-631-4758    Silver         0      1984   39
# 3  ...  1984-03-11    TN  798-631-4758    Silver         0      1984   39
# 4  ...  1986-05-01    MA  413-187-7945    Silver         0      1986   37
#
#    Age_Type Month_no  Year
# 0     Adult       11  2017
# 1  Children       10  2018
# 2     Adult        2  2018
# 3     Adult        4  2018
# 4     Adult        6  2018
#
# [5 rows x 21 columns]

# %%
# Is there any similarity in the amount claimed by males and females?
gender=final.groupby(['gender'])[['claim_amount']].mean()
gender
# Out:
#         claim_amount
# gender
# Female  12062.634707
# Male    12853.058506

# %%
male = final.loc[ final.gender == 'Male', 'claim_amount' ]
female = final.loc[ final.gender == 'Female', 'claim_amount']
male_mean = male.mean()
female_mean = female.mean()

# %%
# Null Hypothesis:There is similarity in the amount claimed by males and females
# Alternate Hypothesis:There is no similarity in the amount claimed by males and females
# Significant values:0.05
# Experiment
import scipy.stats as stats
_,p_value=stats.ttest_ind(a=male,b=female,equal_var=False)
# Since p-value > Significant_value
# we conclude to say that we are failed to reject null Hypothesis

# %%
final.columns
# Out:
# Index(['claim_id', 'customer_id', 'incident_cause', 'claim_date', 'claim_area',
#        'police_report', 'claim_type', 'claim_amount', 'total_policy_claims',
#        'fraudulent', 'gender', 'DateOfBirth', 'State', 'Contact', 'Segment',
#        'Aler_flag', 'DOB_Year', 'Age', 'Age_Type', 'Month_no', 'Year'],
#       dtype='object')

# %%
# Is there any relationship between age category and segment?
relation=pd.crosstab(final['Segment'],final['Age_Type'])
relation
# Out:
# Age_Type  Adult  Children  Youth
# Segment
# Gold        200       119     56
# Platinum    187       116     59
# Silver      170       119     59

# %%
# The current year has shown a significant rise in claim amounts as compared to 2016-17 fiscal average which was $10,000.

print('Claimed amount mean is',final['claim_amount'].mean())
claim_amount=final['claim_amount']
# Out:
# Claimed amount mean is 12467.681372549021

# %%
# Is there any difference between age groups and insurance claims?
Adult_claim_amount = final.loc[final['Age_Type'] == 'Adult','claim_amount']
Adult_claim_amount
Children_claim_amount = final.loc[final['Age_Type'] == 'Children','claim_amount']
Youth_claim_amount = final.loc[final['Age_Type'] == 'Youth','claim_amount']

# %%
stats.f_oneway(Adult_claim_amount,Children_claim_amount,Youth_claim_amount)
# Out:
# F_onewayResult(statistic=0.5434350408775986, pvalue=0.5809083481652482)

# %%
# Is there any relationship between total number of policy claims and the claimed amount?
final.head()
Claim1 = final.loc[ final['total_policy_claims'] == 1.0, 'claim_amount' ]
Claim2 = final.loc[ final['total_policy_claims'] == 2.0, 'claim_amount' ]
Claim3 = final.loc[ final['total_policy_claims'] == 3.0, 'claim_amount' ]
Claim4 = final.loc[ final['total_policy_claims'] == 4.0, 'claim_amount' ]
Claim5 = final.loc[ final['total_policy_claims'] == 5.0, 'claim_amount' ]
Claim6 = final.loc[ final['total_policy_claims'] == 6.0, 'claim_amount' ]
Claim7 = final.loc[ final['total_policy_claims'] == 7.0, 'claim_amount' ]
Claim8 = final.loc[ final['total_policy_claims'] == 8.0, 'claim_amount' ]

# %%
stats.f_oneway(Claim1,Claim2,Claim3,Claim4,Claim5,Claim6,Claim7,Claim8)
# Out:
# F_onewayResult(statistic=0.8524279319141894, pvalue=0.5439242016439254)

# %%
# Null Hypothesis: There is relationship between total number of policy claims and the claimed amount
# Alternate Hypothesis: There is no relationship between total number of policy claims and the claimed amount
# Significance value: 0.05
# Since p-value is greater than Significance value
# we can conclude that we are failed to reject null hypothesis
